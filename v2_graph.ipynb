# %%
from __future__ import division
import numpy as np
import pandas as pd
import os
import glob
import tensorflow as tf
#from skimage import io
#from skimage.util import img_as_float, img_as_ubyte
#import matplotlib.cm as cm
#from matplotlib import pyplot as plt
#%matplotlib inline
import time
from six.moves import xrange

# %%
def get_path(directory):
    imgs = glob.glob(directory + '/images/*.tif')
    imgs.sort()
    #a = [x.split('/')[-1].split('.')[0] for x in train]
    
    mask = glob.glob(directory + '/mask/*.gif')
    mask.sort()
    #b = [x.split('/')[-1].split('.')[0] for x in mask]
    
    gt = glob.glob(directory + '/1st_manual/*.gif')
    gt.sort()
    #c = [x.split('/')[-1].split('.')[0] for x in gt]
    
    return map(os.path.abspath, imgs), map(os.path.abspath, mask), map(os.path.abspath, gt)

train, mask_train, gt_train =  get_path('../Data/DRIVE/training')
test, mask_test, mask_gt = get_path('../Data/DRIVE/test')

# %%
data = pd.read_pickle('../Data/mean_normalised_df.pkl') 
mean_img = pd.read_pickle('../Data/mean_img.pkl')

# %%
# Hyper Params
TOTAL_PATCHES = len(data)
NUM_IMAGES = len(train)
PATCHES_PER_IMAGE = TOTAL_PATCHES/NUM_IMAGES
PATCH_DIM = 31
BATCH_SIZE = 60
LEARNING_RATE = 3e-4
TRAINING_PROP = 0.8
MAX_STEPS = 200
print PATCHES_PER_IMAGE
print MAX_STEPS

NUM_CLASSES = 2
# Out:
# 30.0
# 200

# %%
def next_batch(size, df, current_batch_ind):
    """Returns the next mini batch of data from the dataset passed
    
    Args:
        size: length of the current requested mini batch
        df: the data set consisting of the images and the labels
        current_batch_ind: the current position of the index in the dataset
    
    Returns:
        (batch_x, batch_y): A tuple of np arrays of dimensions 
                        [size, patch_dim**2*3] and [size, NUM_CLASSES] respectively 
        current_batch_ind: the updated current position of the index in the dataset
        df: when the requested batch_size+current_batch_ind is more than the length of the data set,
            the data is shuffled again and current_batch_ind is reset to 0, and this new data set is
            returned
    
    """
    
    if current_batch_ind + size> len(df):
        current_batch_ind = 0
        df = df.iloc[np.random.permutation(len(df))]
        df = df.reset_index(drop=True)
        
    batch_x = np.zeros((size, PATCH_DIM**2*3))
    batch_y = np.zeros((size, NUM_CLASSES), dtype = 'uint8')
    for i in range(current_batch_ind, current_batch_ind+size):
        batch_x[i - current_batch_ind] = df.loc[i][:-1]
        batch_y[i - current_batch_ind][int(df.loc[i][PATCH_DIM**2*3])]=1
        
    current_batch_ind += size  
    return (batch_x, batch_y), current_batch_ind, df

# %%
def inference(images, keep_prob, fc_hidden_units1=512):
    """ Builds the model as far as is required for running the network
    forward to make predictions.

    Args:
        images: Images placeholder, from inputs().
        keep_prob: Probability used for Droupout in the final Affine Layer
        fc_hidden_units1: Number of hidden neurons in final Affine layer
    Returns:
        softmax_linear: Output tensor with the computed logits.
    """
    with tf.variable_scope('h_conv1') as scope:
        weights = tf.get_variable('weights', shape=[4, 4, 3, 64], 
                                  initializer=tf.contrib.layers.xavier_initializer_conv2d())
        biases = tf.get_variable('biases', shape=[64], initializer=tf.constant_initializer(0.05))
        
        # Flattening the 3D image into a 1D array
        x_image = tf.reshape(images, [-1,PATCH_DIM,PATCH_DIM,3])
        z = tf.nn.conv2d(x_image, weights, strides=[1, 1, 1, 1], padding='VALID')
        h_conv1 = tf.nn.relu(z+biases, name=scope.name)
    with tf.variable_scope('h_conv2') as scope:
        weights = tf.get_variable('weights', shape=[4, 4, 64, 64], 
                                  initializer=tf.contrib.layers.xavier_initializer_conv2d())
        biases = tf.get_variable('biases', shape=[64], initializer=tf.constant_initializer(0.05))
        z = tf.nn.conv2d(h_conv1, weights, strides=[1, 1, 1, 1], padding='SAME')
        h_conv2 = tf.nn.relu(z+biases, name=scope.name)
    
    h_pool1 = tf.nn.max_pool(h_conv2, ksize=[1, 2, 2, 1],
                        strides=[1, 2, 2, 1], padding='SAME', name='h_pool1')
    
    with tf.variable_scope('h_conv3') as scope:
        weights = tf.get_variable('weights', shape=[4, 4, 64, 64], 
                                  initializer=tf.contrib.layers.xavier_initializer_conv2d())
        biases = tf.get_variable('biases', shape=[64], initializer=tf.constant_initializer(0.05))
        z = tf.nn.conv2d(h_pool1, weights, strides=[1, 1, 1, 1], padding='SAME')
        h_conv3 = tf.nn.relu(z+biases, name=scope.name)
        
    h_pool2 = tf.nn.max_pool(h_conv3, ksize=[1, 2, 2, 1],
                        strides=[1, 2, 2, 1], padding='SAME', name='h_pool2')
    
    with tf.variable_scope('h_fc1') as scope:
        weights = tf.get_variable('weights', shape=[7**2*64, fc_hidden_units1], 
                                  initializer=tf.contrib.layers.xavier_initializer())
        biases = tf.get_variable('biases', shape=[fc_hidden_units1], initializer=tf.constant_initializer(0.05))
        h_pool2_flat = tf.reshape(h_pool2, [-1, 7*7*64])
        
        h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, weights) + biases, name = 'h_fc1')
        h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)
        
        
    with tf.variable_scope('h_fc2') as scope:
        weights = tf.get_variable('weights', shape=[fc_hidden_units1, NUM_CLASSES], 
                                  initializer=tf.contrib.layers.xavier_initializer())
        biases = tf.get_variable('biases', shape=[NUM_CLASSES])
        
        logits = (tf.matmul(h_fc1_drop, weights) + biases)
    return logits

# %%
def calc_loss(logits, labels):
    """Calculates the loss from the logits and the labels.
    Args:
        logits: Logits tensor, float - [batch_size, NUM_CLASSES].
        labels: Labels tensor, int32 - [batch_size].
    Returns:
        loss: Loss tensor of type float.
    """
    labels = tf.to_float(labels)
    cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits, labels, name='xentropy')
    loss = tf.reduce_mean(cross_entropy, name='xentropy_mean')
    return loss

# %%
def training(loss, learning_rate=5e-4):
    """Sets up the training Ops.
    Creates a summarizer to track the loss over time in TensorBoard.
    Creates an optimizer and applies the gradients to all trainable variables.
    The Op returned by this function is what must be passed to the
    `sess.run()` call to cause the model to train.
    Args:
        loss: Loss tensor, from loss().
        learning_rate: The learning rate to use for gradient descent.
    Returns:
        train_op: The Op for training.
    """
    # Add a scalar summary for the snapshot loss.
    tf.scalar_summary(loss.op.name, loss)
    # Create the Adam optimizer with the given learning rate.
    optimizer = tf.train.AdamOptimizer(learning_rate)
    # Create a variable to track the global step.
    global_step = tf.Variable(0, name='global_step', trainable=False)
    # Use the optimizer to apply the gradients that minimize the loss
    # (and also increment the global step counter) as a single training step.
    train_op = optimizer.minimize(loss, global_step=global_step)
    return train_op

# %%
def evaluation(logits, labels, topk=1):
    """Evaluate the quality of the logits at predicting the label.
    Args:
        logits: Logits tensor, float - [batch_size, NUM_CLASSES].
        labels: Labels tensor, int32 - [batch_size], with values in the
                  range [0, NUM_CLASSES).
        topk: the number k for 'top-k accuracy'
    Returns:
        A scalar int32 tensor with the number of examples (out of batch_size)
        that were predicted correctly.
    """
    # For a classifier model, we can use the in_top_k Op.
    # It returns a bool tensor with shape [batch_size] that is true for
    # the examples where the label is in the top k (here k=1)
    # of all logits for that example.
    
    correct = tf.nn.in_top_k(logits, tf.reshape(tf.slice(labels, [0,1], [int(labels.get_shape()[0]), 1]),[-1]), topk)
    # Return the number of true entries.
    return tf.reduce_sum(tf.cast(correct, tf.int32))

# %%
def placeholder_inputs(batch_size):
    """Generate placeholder variables to represent the input tensors.
    
    These placeholders are used as inputs by the rest of the model building
    code and will be fed from the downloaded data in the .run() loop, below.
    Args:
        batch_size: The batch size will be baked into both placeholders.
    Returns:
        images_placeholder: Images placeholder.
        labels_placeholder: Labels placeholder.
    """
    # Note that the shapes of the placeholders match the shapes of the full
    # image and label tensors, except the first dimension is now batch_size
    # rather than the full size of the train or test data sets.
    images_placeholder = tf.placeholder(tf.float32, shape=(batch_size, PATCH_DIM**2*3))
    labels_placeholder = tf.placeholder(tf.int32, shape=(batch_size, NUM_CLASSES))
    return images_placeholder, labels_placeholder

# %%
#UPDATE current_img_ind
def fill_feed_dict(data_set, images_pl, labels_pl, current_img_ind, batch_size):
    """Fills the feed_dict for training the given step.
    A feed_dict takes the form of:
    feed_dict = {
                  <placeholder>: <tensor of values to be passed for placeholder>,
                  ....
                }
    Args:
        data_set: The set of images and labels, from input_data.read_data_sets()
        images_pl: The images placeholder, from placeholder_inputs().
        labels_pl: The labels placeholder, from placeholder_inputs().
        current_img_ind: The current position of the index in the dataset
    Returns:
        feed_dict: The feed dictionary mapping from placeholders to values.
        current_img_ind: The updated position of the index in the dataset
        data_set: updated data_set
    """
    # Create the feed_dict for the placeholders filled with the next
    # `batch size ` examples.
    batch, current_img_ind, data_set= next_batch(batch_size, data_set, current_img_ind)

    feed_dict = {
      images_pl: batch[0],
      labels_pl: batch[1],
    }
    return feed_dict, current_img_ind, data_set

# %%
def do_eval(sess, eval_correct, images_placeholder, labels_placeholder, data_set, batch_size):
    """Runs one evaluation against the full epoch of data.
    Args:
        sess: The session in which the model has been trained.
        eval_correct: The Tensor that returns the number of correct predictions.
        images_placeholder: The images placeholder.
        labels_placeholder: The labels placeholder.
        data_set: The set of images and labels to evaluate, from
                input_data.read_data_sets().
    """
    # And run one epoch of eval.
    true_count = 0  # Counts the number of correct predictions.
    steps_per_epoch = len(data_set) // batch_size
    num_examples = steps_per_epoch * batch_size
    current_img_ind = 0
    for step in xrange(steps_per_epoch):
        feed_dict, current_img_ind, data_set = fill_feed_dict(data_set, images_placeholder,
                               labels_placeholder, current_img_ind, batch_size)
        true_count += sess.run(eval_correct, feed_dict=feed_dict)
    precision = true_count / num_examples
    print('  Num examples: %d  Num correct: %d  Precision @ 1: %0.04f' %
            (num_examples, true_count, precision))

# %%
def run_training():
    """Train for a number of steps."""
    # Tell TensorFlow that the model will be built into the default Graph.
    train_data = data[:int(TRAINING_PROP*len(data))]
    test_data = data[int(TRAINING_PROP*len(data)):]
    train_data = train_data.reset_index(drop = True)
    test_data = test_data.reset_index(drop = True)
    
    with tf.Graph().as_default():
        # Generate placeholders for the images and labels.
        images_placeholder, labels_placeholder = placeholder_inputs(BATCH_SIZE)

        # Build a Graph that computes predictions from the inference model.
        logits = inference(images_placeholder, 0.5, 512)

        # Add to the Graph the Ops for loss calculation.
        loss = calc_loss(logits, labels_placeholder)

        # Add to the Graph the Ops that calculate and apply gradients.
        train_op = training(loss, LEARNING_RATE)

        # Add the Op to compare the logits to the labels during evaluation.
        eval_correct = evaluation(logits, labels_placeholder)

        # Build the summary operation based on the TF collection of Summaries.
        #summary_op = tf.merge_all_summaries()

        # Create a saver for writing training checkpoints.
        #saver = tf.train.Saver()

        # Create a session for running Ops on the Graph.
        sess = tf.Session()

        # Run the Op to initialize the variables.
        init = tf.initialize_all_variables()
        sess.run(init)

        # Instantiate a SummaryWriter to output summaries and the Graph.
        #summary_writer = tf.train.SummaryWriter('../Data/', sess.graph)
        current_img_ind = 0
        # And then after everything is built, start the training loop.
        for step in xrange(MAX_STEPS):
            start_time = time.time()

            # Fill a feed dictionary with the actual set of images and labels
            # for this particular training step.
            feed_dict, current_img_ind, train_data = fill_feed_dict(train_data,
                                 images_placeholder,
                                 labels_placeholder, current_img_ind=current_img_ind, 
                                                        batch_size=BATCH_SIZE)
            

            # Run one step of the model.  The return values are the activations
            # from the `train_op` (which is discarded) and the `loss` Op.  To
            # inspect the values of your Ops or variables, you may include them
            # in the list passed to sess.run() and the value tensors will be
            # returned in the tuple from the call.
            _, loss_value = sess.run([train_op, loss],
                               feed_dict=feed_dict)

            duration = time.time() - start_time

            # Write the summaries and print an overview fairly often.
            if step % 1 == 0:
                # Print status to stdout.
                print('Step %d: loss = %.2f (%.3f sec)' % (step, loss_value, duration))
                # Update the events file.
                #summary_str = sess.run(summary_op, feed_dict=feed_dict)
                #summary_writer.add_summary(summary_str, step)
                #summary_writer.flush()

            # Save a checkpoint and evaluate the model periodically.
            if (step + 1) % (5) == 0 or (step + 1) == MAX_STEPS:
                #saver.save(sess, '../Data/', global_step=step)
                # Evaluate against the training set.
                print('Training Data Eval:')
                do_eval(sess, eval_correct, images_placeholder, labels_placeholder, train_data, BATCH_SIZE)
                # Evaluate against the validation set.
                print('Validation Data Eval:')
                do_eval(sess, eval_correct, images_placeholder, labels_placeholder, test_data, BATCH_SIZE)

# %%
run_training()
# Out:
# Step 0: loss = 7.60 (1.186 sec)
# Step 1: loss = 5.93 (1.151 sec)
# Step 2: loss = 1.38 (1.275 sec)
# Step 3: loss = 4.09 (1.179 sec)
# Step 4: loss = 9.62 (1.245 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 407  Precision @ 1: 0.8479
# Validation Data Eval:
#   Num examples: 120  Num correct: 103  Precision @ 1: 0.8583
# Step 5: loss = 2.83 (1.182 sec)
# Step 6: loss = 2.06 (1.189 sec)
# Step 7: loss = 3.24 (1.166 sec)
# Step 8: loss = 0.64 (1.191 sec)
# Step 9: loss = 1.18 (1.164 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 270  Precision @ 1: 0.5625
# Validation Data Eval:
#   Num examples: 120  Num correct: 62  Precision @ 1: 0.5167
# Step 10: loss = 1.21 (1.160 sec)
# Step 11: loss = 1.21 (1.339 sec)
# Step 12: loss = 0.80 (1.217 sec)
# Step 13: loss = 0.54 (1.224 sec)
# Step 14: loss = 1.21 (1.183 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 394  Precision @ 1: 0.8208
# Validation Data Eval:
#   Num examples: 120  Num correct: 100  Precision @ 1: 0.8333
# Step 15: loss = 0.42 (1.283 sec)
# Step 16: loss = 0.48 (1.184 sec)
# Step 17: loss = 0.59 (1.264 sec)
# Step 18: loss = 0.49 (1.273 sec)
# Step 19: loss = 0.44 (1.252 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 371  Precision @ 1: 0.7729
# Validation Data Eval:
#   Num examples: 120  Num correct: 90  Precision @ 1: 0.7500
# Step 20: loss = 0.86 (1.262 sec)
# Step 21: loss = 0.37 (1.306 sec)
# Step 22: loss = 0.45 (1.295 sec)
# Step 23: loss = 0.48 (1.253 sec)
# Step 24: loss = 0.65 (1.268 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 401  Precision @ 1: 0.8354
# Validation Data Eval:
#   Num examples: 120  Num correct: 100  Precision @ 1: 0.8333
# Step 25: loss = 0.55 (1.266 sec)
# Step 26: loss = 0.52 (1.276 sec)
# Step 27: loss = 0.47 (1.251 sec)
# Step 28: loss = 0.51 (1.239 sec)
# Step 29: loss = 0.46 (1.231 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 403  Precision @ 1: 0.8396
# Validation Data Eval:
#   Num examples: 120  Num correct: 100  Precision @ 1: 0.8333
# Step 30: loss = 0.32 (1.174 sec)
# Step 31: loss = 0.39 (1.270 sec)
# Step 32: loss = 0.44 (1.271 sec)
# Step 33: loss = 0.44 (1.242 sec)
# Step 34: loss = 0.51 (1.238 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 407  Precision @ 1: 0.8479
# Validation Data Eval:
#   Num examples: 120  Num correct: 100  Precision @ 1: 0.8333
# Step 35: loss = 0.47 (1.276 sec)
# Step 36: loss = 0.43 (1.225 sec)
# Step 37: loss = 0.27 (1.153 sec)
# Step 38: loss = 0.43 (1.158 sec)
# Step 39: loss = 0.40 (1.291 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 407  Precision @ 1: 0.8479
# Validation Data Eval:
#   Num examples: 120  Num correct: 101  Precision @ 1: 0.8417
# Step 40: loss = 0.45 (1.254 sec)
# Step 41: loss = 0.57 (1.158 sec)
# Step 42: loss = 0.41 (1.138 sec)
# Step 43: loss = 0.60 (1.144 sec)
# Step 44: loss = 0.42 (1.160 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 411  Precision @ 1: 0.8562
# Validation Data Eval:
#   Num examples: 120  Num correct: 103  Precision @ 1: 0.8583
# Step 45: loss = 0.34 (1.151 sec)
# Step 46: loss = 0.27 (1.162 sec)
# Step 47: loss = 0.39 (1.145 sec)
# Step 48: loss = 0.38 (1.182 sec)
# Step 49: loss = 0.32 (1.234 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 413  Precision @ 1: 0.8604
# Validation Data Eval:
#   Num examples: 120  Num correct: 101  Precision @ 1: 0.8417
# Step 50: loss = 0.47 (1.230 sec)
# Step 51: loss = 0.43 (1.237 sec)
# Step 52: loss = 0.32 (1.240 sec)
# Step 53: loss = 0.39 (1.270 sec)
# Step 54: loss = 0.39 (1.459 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 415  Precision @ 1: 0.8646
# Validation Data Eval:
#   Num examples: 120  Num correct: 103  Precision @ 1: 0.8583
# Step 55: loss = 0.40 (1.520 sec)
# Step 56: loss = 0.53 (1.317 sec)
# Step 57: loss = 0.23 (1.486 sec)
# Step 58: loss = 0.42 (1.234 sec)
# Step 59: loss = 0.22 (1.261 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 418  Precision @ 1: 0.8708
# Validation Data Eval:
#   Num examples: 120  Num correct: 101  Precision @ 1: 0.8417
# Step 60: loss = 0.32 (1.207 sec)
# Step 61: loss = 0.36 (1.184 sec)
# Step 62: loss = 0.57 (1.189 sec)
# Step 63: loss = 0.49 (1.180 sec)
# Step 64: loss = 0.30 (1.181 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 422  Precision @ 1: 0.8792
# Validation Data Eval:
#   Num examples: 120  Num correct: 103  Precision @ 1: 0.8583
# Step 65: loss = 0.27 (1.167 sec)
# Step 66: loss = 0.41 (1.170 sec)
# Step 67: loss = 0.35 (1.183 sec)
# Step 68: loss = 0.39 (1.175 sec)
# Step 69: loss = 0.45 (1.174 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 423  Precision @ 1: 0.8812
# Validation Data Eval:
#   Num examples: 120  Num correct: 104  Precision @ 1: 0.8667
# Step 70: loss = 0.44 (1.231 sec)
# Step 71: loss = 0.37 (1.234 sec)
# Step 72: loss = 0.35 (1.199 sec)
# Step 73: loss = 0.38 (1.249 sec)
# Step 74: loss = 0.27 (1.213 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 420  Precision @ 1: 0.8750
# Validation Data Eval:
#   Num examples: 120  Num correct: 103  Precision @ 1: 0.8583
# Step 75: loss = 0.34 (1.171 sec)
# Step 76: loss = 0.31 (1.402 sec)
# Step 77: loss = 0.38 (1.373 sec)
# Step 78: loss = 0.36 (1.233 sec)
# Step 79: loss = 0.40 (1.149 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 425  Precision @ 1: 0.8854
# Validation Data Eval:
#   Num examples: 120  Num correct: 106  Precision @ 1: 0.8833
# Step 80: loss = 0.29 (1.161 sec)
# Step 81: loss = 0.30 (1.166 sec)
# Step 82: loss = 0.21 (1.162 sec)
# Step 83: loss = 0.31 (1.135 sec)
# Step 84: loss = 0.40 (1.160 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 427  Precision @ 1: 0.8896
# Validation Data Eval:
#   Num examples: 120  Num correct: 107  Precision @ 1: 0.8917
# Step 85: loss = 0.35 (1.173 sec)
# Step 86: loss = 0.38 (1.164 sec)
# Step 87: loss = 0.40 (1.176 sec)
# Step 88: loss = 0.30 (1.151 sec)
# Step 89: loss = 0.33 (1.175 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 434  Precision @ 1: 0.9042
# Validation Data Eval:
#   Num examples: 120  Num correct: 107  Precision @ 1: 0.8917
# Step 90: loss = 0.42 (1.159 sec)
# Step 91: loss = 0.37 (1.178 sec)
# Step 92: loss = 0.30 (1.155 sec)
# Step 93: loss = 0.36 (1.175 sec)
# Step 94: loss = 0.24 (1.142 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 432  Precision @ 1: 0.9000
# Validation Data Eval:
#   Num examples: 120  Num correct: 104  Precision @ 1: 0.8667
# Step 95: loss = 0.27 (1.148 sec)
# Step 96: loss = 0.31 (1.190 sec)
# Step 97: loss = 0.31 (1.145 sec)
# Step 98: loss = 0.28 (1.178 sec)
# Step 99: loss = 0.25 (1.178 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 435  Precision @ 1: 0.9062
# Validation Data Eval:
#   Num examples: 120  Num correct: 105  Precision @ 1: 0.8750
# Step 100: loss = 0.25 (1.169 sec)
# Step 101: loss = 0.30 (1.195 sec)
# Step 102: loss = 0.29 (1.191 sec)
# Step 103: loss = 0.41 (1.173 sec)
# Step 104: loss = 0.25 (1.177 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 429  Precision @ 1: 0.8938
# Validation Data Eval:
#   Num examples: 120  Num correct: 105  Precision @ 1: 0.8750
# Step 105: loss = 0.22 (1.182 sec)
# Step 106: loss = 0.37 (1.154 sec)
# Step 107: loss = 0.32 (1.161 sec)
# Step 108: loss = 0.26 (1.145 sec)
# Step 109: loss = 0.28 (1.165 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 439  Precision @ 1: 0.9146
# Validation Data Eval:
#   Num examples: 120  Num correct: 105  Precision @ 1: 0.8750
# Step 110: loss = 0.37 (1.180 sec)
# Step 111: loss = 0.27 (1.169 sec)
# Step 112: loss = 0.26 (1.172 sec)
# Step 113: loss = 0.24 (1.154 sec)
# Step 114: loss = 0.35 (1.178 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 440  Precision @ 1: 0.9167
# Validation Data Eval:
#   Num examples: 120  Num correct: 108  Precision @ 1: 0.9000
# Step 115: loss = 0.34 (1.157 sec)
# Step 116: loss = 0.26 (1.175 sec)
# Step 117: loss = 0.17 (1.159 sec)
# Step 118: loss = 0.40 (1.163 sec)
# Step 119: loss = 0.25 (1.151 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 437  Precision @ 1: 0.9104
# Validation Data Eval:
#   Num examples: 120  Num correct: 108  Precision @ 1: 0.9000
# Step 120: loss = 0.21 (1.165 sec)
# Step 121: loss = 0.26 (1.164 sec)
# Step 122: loss = 0.27 (1.132 sec)
# Step 123: loss = 0.24 (1.149 sec)
# Step 124: loss = 0.18 (1.136 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 440  Precision @ 1: 0.9167
# Validation Data Eval:
#   Num examples: 120  Num correct: 106  Precision @ 1: 0.8833
# Step 125: loss = 0.35 (1.160 sec)
# Step 126: loss = 0.24 (1.200 sec)
# Step 127: loss = 0.21 (1.184 sec)
# Step 128: loss = 0.25 (1.168 sec)
# Step 129: loss = 0.21 (1.195 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 448  Precision @ 1: 0.9333
# Validation Data Eval:
#   Num examples: 120  Num correct: 106  Precision @ 1: 0.8833
# Step 130: loss = 0.22 (1.289 sec)
# Step 131: loss = 0.23 (1.181 sec)
# Step 132: loss = 0.20 (1.291 sec)
# Step 133: loss = 0.13 (1.292 sec)
# Step 134: loss = 0.32 (1.315 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 446  Precision @ 1: 0.9292
# Validation Data Eval:
#   Num examples: 120  Num correct: 107  Precision @ 1: 0.8917
# Step 135: loss = 0.24 (1.266 sec)
# Step 136: loss = 0.33 (1.180 sec)
# Step 137: loss = 0.21 (1.191 sec)
# Step 138: loss = 0.22 (1.197 sec)
# Step 139: loss = 0.23 (1.245 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 453  Precision @ 1: 0.9437
# Validation Data Eval:
#   Num examples: 120  Num correct: 103  Precision @ 1: 0.8583
# Step 140: loss = 0.25 (1.161 sec)
# Step 141: loss = 0.11 (1.140 sec)
# Step 142: loss = 0.24 (1.175 sec)
# Step 143: loss = 0.23 (1.202 sec)
# Step 144: loss = 0.11 (1.183 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 448  Precision @ 1: 0.9333
# Validation Data Eval:
#   Num examples: 120  Num correct: 108  Precision @ 1: 0.9000
# Step 145: loss = 0.29 (1.227 sec)
# Step 146: loss = 0.17 (1.268 sec)
# Step 147: loss = 0.19 (1.267 sec)
# Step 148: loss = 0.32 (1.291 sec)
# Step 149: loss = 0.18 (1.208 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 458  Precision @ 1: 0.9542
# Validation Data Eval:
#   Num examples: 120  Num correct: 106  Precision @ 1: 0.8833
# Step 150: loss = 0.16 (1.190 sec)
# Step 151: loss = 0.18 (1.192 sec)
# Step 152: loss = 0.23 (1.219 sec)
# Step 153: loss = 0.18 (1.201 sec)
# Step 154: loss = 0.15 (1.209 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 460  Precision @ 1: 0.9583
# Validation Data Eval:
#   Num examples: 120  Num correct: 108  Precision @ 1: 0.9000
# Step 155: loss = 0.11 (1.216 sec)
# Step 156: loss = 0.20 (1.187 sec)
# Step 157: loss = 0.31 (1.163 sec)
# Step 158: loss = 0.11 (1.185 sec)
# Step 159: loss = 0.16 (1.195 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 458  Precision @ 1: 0.9542
# Validation Data Eval:
#   Num examples: 120  Num correct: 110  Precision @ 1: 0.9167
# Step 160: loss = 0.11 (1.263 sec)
# Step 161: loss = 0.15 (1.183 sec)
# Step 162: loss = 0.09 (1.202 sec)
# Step 163: loss = 0.15 (1.238 sec)
# Step 164: loss = 0.17 (1.302 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 459  Precision @ 1: 0.9563
# Validation Data Eval:
#   Num examples: 120  Num correct: 108  Precision @ 1: 0.9000
# Step 165: loss = 0.19 (1.176 sec)
# Step 166: loss = 0.15 (1.327 sec)
# Step 167: loss = 0.29 (1.144 sec)
# Step 168: loss = 0.19 (1.190 sec)
# Step 169: loss = 0.29 (1.150 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 463  Precision @ 1: 0.9646
# Validation Data Eval:
#   Num examples: 120  Num correct: 107  Precision @ 1: 0.8917
# Step 170: loss = 0.15 (1.244 sec)
# Step 171: loss = 0.14 (1.185 sec)
# Step 172: loss = 0.10 (1.197 sec)
# Step 173: loss = 0.24 (1.289 sec)
# Step 174: loss = 0.13 (1.195 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 467  Precision @ 1: 0.9729
# Validation Data Eval:
#   Num examples: 120  Num correct: 110  Precision @ 1: 0.9167
# Step 175: loss = 0.07 (1.193 sec)
# Step 176: loss = 0.13 (1.200 sec)
# Step 177: loss = 0.12 (1.238 sec)
# Step 178: loss = 0.10 (1.192 sec)
# Step 179: loss = 0.18 (1.195 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 464  Precision @ 1: 0.9667
# Validation Data Eval:
#   Num examples: 120  Num correct: 108  Precision @ 1: 0.9000
# Step 180: loss = 0.07 (1.211 sec)
# Step 181: loss = 0.19 (1.242 sec)
# Step 182: loss = 0.15 (1.187 sec)
# Step 183: loss = 0.10 (1.247 sec)
# Step 184: loss = 0.11 (1.254 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 470  Precision @ 1: 0.9792
# Validation Data Eval:
#   Num examples: 120  Num correct: 107  Precision @ 1: 0.8917
# Step 185: loss = 0.10 (1.236 sec)
# Step 186: loss = 0.11 (1.158 sec)
# Step 187: loss = 0.14 (1.232 sec)
# Step 188: loss = 0.10 (1.253 sec)
# Step 189: loss = 0.18 (1.258 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 462  Precision @ 1: 0.9625
# Validation Data Eval:
#   Num examples: 120  Num correct: 108  Precision @ 1: 0.9000
# Step 190: loss = 0.16 (1.203 sec)
# Step 191: loss = 0.07 (1.241 sec)
# Step 192: loss = 0.15 (1.208 sec)
# Step 193: loss = 0.08 (1.185 sec)
# Step 194: loss = 0.11 (1.247 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 471  Precision @ 1: 0.9812
# Validation Data Eval:
#   Num examples: 120  Num correct: 110  Precision @ 1: 0.9167
# Step 195: loss = 0.06 (1.194 sec)
# Step 196: loss = 0.11 (1.204 sec)
# Step 197: loss = 0.10 (1.201 sec)
# Step 198: loss = 0.10 (1.232 sec)
# Step 199: loss = 0.07 (1.173 sec)
# Training Data Eval:
#   Num examples: 480  Num correct: 467  Precision @ 1: 0.9729
# Validation Data Eval:
#   Num examples: 120  Num correct: 108  Precision @ 1: 0.9000
